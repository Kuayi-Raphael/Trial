# %% [markdown]
# ### Name:Adika Nathaniel
#
# # ID:10957036

# %% [markdown]
# ##### import statements for libraries

# %% [markdown]
# import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
data=pd.read_csv('data.csv')

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
data=data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 175.1 KB

# %% [markdown]
# ## Explaining the method of handling null values:
#
# The mean was used to replace the null values and missing data.This was to cater for better analysis from data.

# %%
mean_fa=data["fixed acidity"].mean()

# %% [markdown]
# mean_fa

# %%
data["fixed acidity"]=data["fixed acidity"].fillna(mean_fa)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 175.1 KB

# %%
mean_ca=data["citric acid"].mean()

# %%
mean_ca
# Out:
# 0.271175

# %%
data["citric acid"]=data["citric acid"].fillna(mean_ca)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 175.1 KB

# %%
mean_c=data["chlorides"].mean()

# %%
data["chlorides"]=data["chlorides"].fillna(mean_c)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free sulfur dioxide   1601 non-null   float64
#  7   total sulfur dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 175.1 KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 175.1 KB

# %%
mean_sfd=data["free sulfur dioxide"].mean()

# %%
data["free sulfur dioxide"]=data["free sulfur dioxide"].fillna(mean_sfd)

# %%
mean_tsd=data["total sulfur dioxide"].mean()

# %%
data["total sulfur dioxide"]=data["total sulfur dioxide"].fillna(mean_tsd)

# %%
mean_d=data["density"].mean()

# %%
data["density"]=data["density"].fillna(mean_d)

# %%
mean_pH=data["pH"].mean()

# %%
data["pH"]=data["pH"].fillna(mean_pH)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free sulfur dioxide   1601 non-null   float64
#  7   total sulfur dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 175.1 KB

# %%
mean_q=data["quality"].mean()

# %%
data["quality"]=data["quality"].fillna(mean_q)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free sulfur dioxide   1601 non-null   float64
#  7   total sulfur dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 175.1 KB

# %% [markdown]
# ### Removing all duplicate rows of data

# %%
data=data.drop_duplicates()

# %% [markdown]
# ### Updated data

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density        pH  \
# ...

# %%
data.sample(20)
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 215    216            7.0             0.490         0.49            5.60
# 855    856            7.6             0.735         0.02            2.50
# 30      31            6.7             0.675         0.07            2.40
# 892    893           10.1             0.450         0.23            1.90
# 595    596            8.9             0.595         0.41            7.90
# 1271  1272            7.3             0.440         0.20            1.60
# 782    783            9.0             0.820         0.05            2.40
# 1051  1052            8.5             0.460         0.59            1.40
# 1470  1471           10.0             0.690         0.11            1.40
# 381    382           13.7             0.415         0.68            2.90
# 1455  1456            6.5             0.900         0.00            1.60
# 586    587           11.1             0.310         0.49            2.70
# ...

# %% [markdown]
# ## Statistical Inferences of the entire dataset:

# %%
data.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %% [markdown]
# ## Statistical Inferences of individual columns:

# %%
data['fixed acidity'].describe()
# Out:
# count    1601.000000
# mean        8.319875
# std         1.739495
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %%
data['volatile acidity'].describe()
# Out:
# count    1601.000000
# mean        0.527742
# std         0.178981
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile acidity, dtype: float64

# %%
data['citric acid'].describe()
# Out:
# count    1601.000000
# mean        0.271175
# std         0.194684
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64

# %%
data['residual sugar'].describe()
# Out:
# count    1601.000000
# mean        2.538445
# std         1.409138
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual sugar, dtype: float64

# %%
data['chlorides'].describe()
# Out:
# count    1601.000000
# mean        0.087487
# std         0.047032
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %%
data['free sulfur dioxide'].describe()
# Out:
# count    1601.000000
# mean       15.886875
# std        10.455218
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free sulfur dioxide, dtype: float64

# %%
data['total sulfur dioxide'].describe()
# Out:
# count    1601.000000
# mean       46.520000
# std        32.967416
# min         6.000000
# 25%        22.000000
# 50%        38.000000
# 75%        62.000000
# max       289.000000
# Name: total sulfur dioxide, dtype: float64

# %%
data['density'].describe()
# Out:
# count    1601.000000
# mean        0.996746
# std         0.001887
# min         0.990070
# 25%         0.995600
# 50%         0.996750
# 75%         0.997830
# max         1.003690
# Name: density, dtype: float64

# %%
data['pH'].describe()
# Out:
# count    1601.000000
# mean        3.311106
# std         0.154290
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
data['sulphates'].describe()
# Out:
# count    1601.000000
# mean        0.658220
# std         0.169471
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
data['alcohol'].describe()
# Out:
# count    1601.000000
# mean       10.423204
# std         1.065495
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
data['quality'].describe()
# Out:
# count    1601.000000
# mean        5.636250
# std         0.807116
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %% [markdown]
# ## Various Histograms for data visualisation

# %%
data['fixed acidity'].plot(kind='hist',title='A histogram of fixed acidity',color="green")
# Out:
# <Axes: title={'center': 'A histogram of fixed acidity'}, ylabel='Frequency'>

# %%
data['total sulfur dioxide'].plot(kind='hist',title="A histogram of total sulfur dioxide",color="green");

# %%
data['alcohol'].plot(kind='hist',title="A histogram of alcohol",color="green");

# %%
data['pH'].plot(kind='hist',title="A histogram of pH",color="green");

# %% [markdown]
# # Scatterplots of Quality Against Various Columns

# %%
data.plot(x='quality', y='alcohol', kind='scatter',color="purple");
data.plot(x='quality', y='pH', kind='scatter',color="purple");
data.plot(x='quality', y='volatile acidity', kind='scatter',color="purple");
data.plot(x='quality', y='residual sugar', kind='scatter',color="purple");

# %% [markdown]
# ### boxplot of alcohol

# %%
data["alcohol"].plot(kind="box",ylabel="Alcohol",color="red",title="A boxplot of alcohol")
# Out:
# <Axes: title={'center': 'A boxplot of alcohol'}, ylabel='Alcohol'>

# %% [markdown]
# # Heatmap of correlation

# %%
dataCorrelation=data.corr()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(dataCorrelation,annot=True,cmap="Blues",linewidths=10,ax=ax, cbar_kws={'label': 'Correlation'},xticklabels=45, annot_kws={"fontsize": 8})
plt.title("Data Correlation Heatmap",fontdict={"fontsize": 16})
plt.show()

# %% [markdown]
# # Subplots of pH and citric acid by quality

# %%
fig, ax = plt.subplots(2, 1, figsize=(6, 8))
ax[0].scatter(data['pH'], data['quality'], alpha=0.2)
ax[0].set_xlabel('pH')
ax[0].set_ylabel('Quality')
ax[0].set_title('pH vs Quality')
ax[1].scatter(data['citric acid'], data['quality'], alpha=0.2)
ax[1].set_xlabel('Citric Acid')
ax[1].set_ylabel('Quality')
ax[1].set_title('Citric Acid vs Quality')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Bar graph of alcohol content by quality

# %%
mean_alcohol = data.groupby('quality')['alcohol'].mean()
plt.bar(mean_alcohol.index, mean_alcohol)
plt.title('Average Alcohol Content by Quality')
plt.xlabel('Quality')
plt.ylabel('Alcohol (%)')
plt.show()

# %% [markdown]
# # Pie chart of distribution of wine quality rating

# %%
# get the counts of each quality rating 
counts = data['quality'].value_counts()

# create a pie chart
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(counts)
ax.set_title('Distribution of Wine Quality Ratings')
ax.legend(bbox_to_anchor=(1.2, 1), labels=["{}: {:.1f}%".format(label, value/sum(counts)*100) for label, value in zip(counts.index, counts)])

plt.show()
